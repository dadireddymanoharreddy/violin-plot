# %%
# Import pandas and read the csv file
import pandas as pd
data = pd.read_csv("/content/cri t20.csv")

# %%
# Display the first ten rows
data.head()
# Out:
#               Player       Span  Mat  Inns  NO  Runs    HS    Ave    BF  \
# 0  RG Sharma (INDIA)  2007-2022  136   128  16  3620   118  32.32  2574
# 1    V Kohli (INDIA)  2010-2022  104    96  27  3584  122*  51.94  2590
# 2    MJ Guptill (NZ)  2009-2022  121   117   7  3497   105  31.79  2575
# 3  PR Stirling (IRE)  2009-2022  114   113   8  3011  115*  28.67  2233
# 4     AJ Finch (AUS)  2011-2022   92    92  11  2855   172  35.24  1965
#
#        SR  100  50   0   4s   6s
# 0  140.63    4  28   8  323  171
# 1  138.37    1  32   4  319  104
# 2  135.80    2  20   3  306  172
# 3  134.84    1  20  10  344  111
# 4  145.29    2  17   7  286  117

# %%
data.describe()
# Out:
#               Mat        Inns         NO         Runs        Ave           BF  \
# count   29.000000   29.000000  29.000000    29.000000  29.000000    29.000000
# mean    92.275862   87.206897  13.517241  2298.724138  32.043448  1730.655172
# std     21.400762   19.767179   8.020602   553.714334   7.246753   392.783408
# min     61.000000   51.000000   3.000000  1724.000000  21.210000  1102.000000
# 25%     77.000000   75.000000   7.000000  1934.000000  27.920000  1503.000000
# 50%     91.000000   86.000000  11.000000  2045.000000  31.210000  1567.000000
# 75%    110.000000  103.000000  18.000000  2514.000000  33.550000  1938.000000
# max    136.000000  128.000000  33.000000  3620.000000  51.940000  2590.000000
#
#                SR        100         50          0          4s          6s
# count   29.000000  29.000000  29.000000  29.000000   29.000000   29.000000
# mean   132.994138   1.068966  14.103448   4.965517  210.482759   85.137931
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="dark")
sns.violinplot(x=data["Ave"], palette="Blues")
plt.title("Violin Plot")
plt.show()
